# %% [markdown]
# # Finance Data Pre-processing
#
# 1. import data by yfinance
# 2. calculate the SMA
# 3. export data to csv by pandas

# %% [markdown]
# ## 1. import data by yfinance

# %%
import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")
print(nvda)
"""
returns
<yfinance.Ticker object at 0x1a1715e898>
"""
# Out:
# yfinance.Ticker object <NVDA>
# '\nreturns\n<yfinance.Ticker object at 0x1a1715e898>\n'

# %%
# get stock info
nvda.info
# Out:
# {'zip': '95051',
#  'sector': 'Technology',
#  'fullTimeEmployees': 13775,
# ...

# %%
# get historical market data (all)
nvda_history = nvda.history(period="max")
nvda_history
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1999-01-22    1.61    1.80    1.43    1.51  67867200.0        0.0
# 1999-01-25    1.63    1.69    1.51    1.67  12762000.0        0.0
# 1999-01-26    1.69    1.72    1.51    1.54   8580000.0        0.0
# 1999-01-27    1.54    1.58    1.46    1.53   6109200.0        0.0
# 1999-01-28    1.53    1.54    1.52    1.53   5688000.0        0.0
# 1999-01-29    1.53    1.53    1.46    1.46   6100800.0        0.0
# 1999-02-01    1.46    1.50    1.46    1.49   3867600.0        0.0
# 1999-02-02    1.46    1.50    1.33    1.37   6602400.0        0.0
# 1999-02-03    1.35    1.42    1.34    1.40   1878000.0        0.0
# 1999-02-04    1.42    1.51    1.40    1.48   4548000.0        0.0
# 1999-02-05    1.50    1.53    1.46    1.52   3421200.0        0.0
# 1999-02-08    1.53    1.53    1.47    1.47   3852000.0        0.0
# 1999-02-09    1.50    1.51    1.39    1.41   2174400.0        0.0
# ...

# %%
# get historical market data (from 2020-01-01 to now)
# today = 
nvda_history = nvda.history(start='2020-01-01',end='2020-05-05')
nvda_history
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2019-12-31  230.76  235.54  229.99  235.16   5775100        0.0             0
# 2020-01-02  238.61  239.77  236.58  239.77   5938400        0.0             0
# 2020-01-03  234.96  237.69  233.96  235.93   5134600        0.0             0
# 2020-01-06  232.18  237.13  231.13  236.92   6565900        0.0             0
# 2020-01-07  238.06  241.63  236.25  239.79   7871400        0.0             0
# 2020-01-08  239.62  241.90  238.01  240.24   6927700        0.0             0
# 2020-01-09  243.70  245.78  240.72  242.87   6377800        0.0             0
# 2020-01-10  247.18  248.40  243.60  244.17   7907400        0.0             0
# 2020-01-13  247.51  252.84  246.60  251.83   7996000        0.0             0
# 2020-01-14  250.11  251.13  246.60  247.13   8977200        0.0             0
# 2020-01-15  247.64  248.54  244.38  245.42   6577600        0.0             0
# ...

# %%
# get 1 day, 1 hour interval
nvda_history = nvda.history(period="1d", interval="1h")
nvda_history
# Out:
#               Open    High     Low   Close   Volume  Dividends  Stock Splits
# Date
# 2020-04-14  275.58  281.45  273.89  281.40  3955282          0             0
# 2020-04-14  281.40  281.99  277.25  280.98  2097881          0             0
# 2020-04-14  281.06  284.75  280.92  284.04  1760598          0             0
# 2020-04-14  284.11  284.88  282.34  282.83  1142674          0             0
# 2020-04-14  282.84  285.32  282.83  284.80  1099444          0             0
# 2020-04-14  284.88  285.00  282.24  283.77  1144222          0             0
# 2020-04-14  283.80  284.52  282.68  284.01  1271577          0             0

# %%
# get 1 day
nvda_history = nvda.history(period="5d")
nvda_history

data = nvda_history
data
# Out:
#               Open    High     Low   Close   Volume  Dividends  Stock Splits
# Date
# 2020-04-29  296.77  300.58  293.75  298.46  9479000          0             0
# 2020-04-30  296.29  298.46  291.72  292.28  9397900          0             0
# 2020-05-01  284.35  288.90  280.84  282.78  8552400          0             0
# 2020-05-04  280.88  291.84  280.88  291.29  7925500          0             0
# 2020-05-05  295.47  300.25  291.30  293.74  9066078          0             0

# %%
data
# Out:
#               Open    High     Low   Close   Volume  Dividends  Stock Splits
# Date
# 2020-04-29  296.77  300.58  293.75  298.46  9479000          0             0
# 2020-04-30  296.29  298.46  291.72  292.28  9397900          0             0
# 2020-05-01  284.35  288.90  280.84  282.78  8552400          0             0
# 2020-05-04  280.88  291.84  280.88  291.29  7925500          0             0
# 2020-05-05  295.47  300.25  291.30  293.74  9066078          0             0

# %%
# reset DataFrame index to RangeIndex
data1 = data.reset_index()
data1
# Out:
#         Date    Open    High     Low   Close   Volume  Dividends  Stock Splits
# 0 2020-04-29  296.77  300.58  293.75  298.46  9479000          0             0
# 1 2020-04-30  296.29  298.46  291.72  292.28  9397900          0             0
# 2 2020-05-01  284.35  288.90  280.84  282.78  8552400          0             0
# 3 2020-05-04  280.88  291.84  280.88  291.29  7925500          0             0
# 4 2020-05-05  295.47  300.25  291.30  293.74  9066078          0             0

# %%
# data1 = data.reset_index()

date = '2020-05-03'
end_date = data1[data1['Date']<=date].tolist()[0] if data1[data1['Date']<=date].any() else None
# end_date = data1.index[data1['Date']<=date].tolist()[0] if data1.index[data1['Date']<=date].any() else None
print(f'end_date:{end_date}')
# data = data[:end_date]
# data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-91f52fca7dae> in <module>()
#       2
#       3 date = '2020-05-03'
# ----> 4 end_date = data1[data1['Date']<=date].tolist()[0] if data1[data1['Date']<=date].any() else None
#       5 # end_date = data1.index[data1['Date']<=date].tolist()[0] if data1.index[data1['Date']<=date].any() else None
#       6 print(f'end_date:{end_date}')
#
# ~/anaconda3/envs/py36-fasttext/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477         raise ValueError("The truth value of a {0} is ambiguous. "
#    1478                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1479                          .format(self.__class__.__name__))
#    1480
#    1481     __bool__ = __nonzero__
#
# ...

# %%
data1[data1['Date']<=date]
# Out:
#         Date    Open    High     Low   Close   Volume  Dividends  Stock Splits
# 0 2020-04-29  296.77  300.58  293.75  298.46  9479000          0             0
# 1 2020-04-30  296.29  298.46  291.72  292.28  9397900          0             0
# 2 2020-05-01  284.35  288.90  280.84  282.78  8552400          0             0

# %%
data1['Close'].iat[-1]
# Out:
# 293.74

# %%
data1
# Out:
#         Date    Open    High     Low   Close   Volume  Dividends  Stock Splits
# 0 2020-04-29  296.77  300.58  293.75  298.46  9479000          0             0
# 1 2020-04-30  296.29  298.46  291.72  292.28  9397900          0             0
# 2 2020-05-01  284.35  288.90  280.84  282.78  8552400          0             0
# 3 2020-05-04  280.88  291.84  280.88  291.29  7925500          0             0
# 4 2020-05-05  295.47  300.25  291.30  293.74  9066078          0             0

# %%
for i in nvda_history.index:
    ma3 = f'xxx:{i}'
    nvda_history.at[i, 'ma3xx'] = ma3

# %%
type(nvda_history)
# Out:
# pandas.core.frame.DataFrame

# %%
nvda_history.shape
# Out:
# (5, 7)

# %% [markdown]
# ## 2. export data to csv

# %%
csv_export_filename = 'nvda.csv'
nvda_history.to_csv(csv_export_filename, header=True)

# %%
stock_ids = ['NVDA']
period = '1y'; start = '2020-04-27'; end='2020-04-28'; group_by='ticker'
data = yf.download(stock_ids, end=end, group_by=group_by)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-01-22    1.750000    1.953125    1.552083    1.640625    1.509998
# 1999-01-25    1.770833    1.833333    1.640625    1.812500    1.668188
# 1999-01-26    1.833333    1.869792    1.645833    1.671875    1.538759
# 1999-01-27    1.677083    1.718750    1.583333    1.666667    1.533965
# 1999-01-28    1.666667    1.677083    1.651042    1.661458    1.529172
# 1999-01-29    1.661458    1.666667    1.583333    1.583333    1.457267
# 1999-02-01    1.583333    1.625000    1.583333    1.614583    1.486029
# 1999-02-02    1.583333    1.625000    1.442708    1.489583    1.370982
# 1999-02-03    1.468750    1.541667    1.458333    1.520833    1.399744
# 1999-02-04    1.541667    1.645833    1.520833    1.604167    1.476442
# 1999-02-05    1.630208    1.666667    1.588542    1.651042    1.519585
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
csv_export_filename = 'nvda.1.csv'
data.to_csv(csv_export_filename, header=True)

# %% [markdown]
# ## 3. Mass download data

# %%
# stocks = "NVDA TSLA UGLD"
stocks = ['NVDA','TSLA','UGLD']
period = '5y' # max, 1y, 5y
data = yf.download(stocks, period="1y", group_by="ticker")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
data = yf.download(stocks, period="1y", start='', end='', group_by="ticker")
print(type(data))
print(data.shape)
# Out:
# [*********************100%***********************]  3 of 3 completed
# <class 'pandas.core.frame.DataFrame'>
# (252, 18)

# %%
data
# Out:
#                   NVDA                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2019-04-29  178.410004  180.449997  175.500000  179.330002  178.709595
# 2019-04-30  178.029999  182.029999  177.259995  181.000000  180.373795
# 2019-05-01  183.110001  184.809998  180.460007  180.470001  179.845642
# 2019-05-02  180.860001  184.869995  179.119995  183.190002  182.556213
# 2019-05-03  183.529999  183.929993  180.529999  183.009995  182.376846
# 2019-05-06  175.500000  180.339996  174.000000  179.850006  179.227768
# 2019-05-07  177.899994  177.899994  171.169998  173.110001  172.511093
# 2019-05-08  172.000000  177.149994  171.520004  173.919998  173.318283
# 2019-05-09  171.139999  171.529999  165.399994  170.190002  169.601212
# 2019-05-10  168.949997  171.589996  164.000000  168.820007  168.235947
# 2019-05-13  163.500000  164.429993  157.809998  158.449997  157.901794
# ...

# %%
data['NVDA'][-1:]
# Out:
#                  Open   High    Low       Close   Adj Close    Volume
# Date
# 2020-04-27  294.98999  303.5  294.0  297.079987  297.079987  11610887

# %%
data['NVDA']['Close'][-1:]
# Out:
# Date
# 2020-04-27    297.079987
# Name: Close, dtype: float64

# %%
data = yf.download(stocks, period="1y", start='', end='')
print(type(data))
print(data.shape)
# Out:
# [*********************100%***********************]  3 of 3 completed
# <class 'pandas.core.frame.DataFrame'>
# (252, 18)

# %%
data
# Out:
#              Adj Close                               Close              \
#                   NVDA        TSLA        UGLD        NVDA        TSLA
# Date
# 2019-04-29  178.709595  241.470001   91.500000  179.330002  241.470001
# 2019-04-30  180.373795  238.690002   92.320000  181.000000  238.690002
# 2019-05-01  179.845642  234.009995   90.449997  180.470001  234.009995
# 2019-05-02  182.556213  244.100006   89.320000  183.190002  244.100006
# 2019-05-03  182.376846  255.029999   90.980003  183.009995  255.029999
# 2019-05-06  179.227768  255.339996   91.349998  179.850006  255.339996
# 2019-05-07  172.511093  247.059998   92.300003  173.110001  247.059998
# 2019-05-08  173.318283  244.839996   91.480003  173.919998  244.839996
# 2019-05-09  169.601212  241.979996   92.089996  170.190002  241.979996
# 2019-05-10  168.235947  239.520004   92.459999  168.820007  239.520004
# 2019-05-13  157.901794  227.009995   95.449997  158.449997  227.009995
# ...

# %%
data['Close'][-1:]
# Out:
#                   NVDA    TSLA        UGLD
# Date
# 2020-04-27  297.079987  798.75  188.550003

# %%
data['Close']['NVDA'][-1:]
# Out:
# Date
# 2020-04-27    297.079987
# Name: NVDA, dtype: float64

# %%
ma3 = pd.DataFrame.rolling(data['NVDA']['Close'], window=3).mean()
ma3.shape

ma3.shape
ma3.tail(5)
# Out:
# Date
# 2020-04-07    257.113332
# 2020-04-08    264.793335
# 2020-04-09    262.976674
# 2020-04-13    266.583344
# 2020-04-14    272.250010
# Name: Close, dtype: float64

# %%
type(data['NVDA']['Close'][-1:])
# Out:
# pandas.core.series.Series

# %%
data['NVDA']['Close'][-1:]
# Out:
# Date
# 2020-04-14    283.950012
# Name: Close, dtype: float64

# %%
type(data['NVDA']['Close'][-1:][0])
# Out:
# numpy.float64

# %%
data['NVDA']['Close'][-1:][0]
# Out:
# 283.95001220703125

# %%
data.describe()
# Out:
#              UGLD                                                  \
#              Open        High         Low       Close   Adj Close
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   133.846746  135.816309  131.759385  133.802143  133.802143
# std     24.578582   25.295969   23.438224   24.232849   24.232849
# min     88.709999   89.639999   88.430000   89.320000   89.320000
# 25%    120.119999  122.714998  119.044998  120.937500  120.937500
# 50%    135.840004  136.915001  133.920006  136.114998  136.114998
# 75%    149.969997  151.415001  147.747505  149.962505  149.962505
# max    203.289993  210.210007  196.205002  202.419998  202.419998
#
#                             TSLA                                      \
#               Volume        Open        High         Low       Close
# count     252.000000  252.000000  252.000000  252.000000  252.000000
# mean   142563.170635  361.713294  371.487381  352.682699  362.333969
# ...

# %%
# Get the NVDA timeseries. This now returns a Pandas Series object indexed by date.
nvda = data.loc[:, 'NVDA']

# %%
type(nvda)
# Out:
# pandas.core.frame.DataFrame

# %%
nvda.shape
# Out:
# (252, 6)

# %%
len(nvda)
# Out:
# 252

# %%
nvda.tail(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-07  277.299988  278.250000  257.299988  259.029999  259.029999
# 2020-04-08  263.410004  267.950012  260.600006  266.950012  266.950012
# 2020-04-09  272.000000  272.920013  260.420013  262.950012  262.950012
# 2020-04-13  260.549988  270.200012  257.000000  269.850006  269.850006
# 2020-04-14  275.000000  285.320007  273.889313  283.950012  283.950012
#
#               Volume
# Date
# 2020-04-07  19613000
# 2020-04-08  13561100
# 2020-04-09  13156200
# 2020-04-13   9933900
# 2020-04-14  13053691

# %%
# get the closing price into new DataFrame
nvda_close = nvda.filter(['Close'], axis=1)

# %%
type(nvda_close)
# Out:
# pandas.core.frame.DataFrame

# %%
nvda_close.shape
# Out:
# (252, 1)

# %%
len(nvda_close)
# Out:
# 252

# %%
nvda_close.tail(5)
# Out:
#                  Close
# Date
# 2020-04-07  259.029999
# 2020-04-08  266.950012
# 2020-04-09  262.950012
# 2020-04-13  269.850006
# 2020-04-14  283.950012

# %%
type(nvda_close.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
nvda_close.index
# Out:
# DatetimeIndex(['2019-04-15', '2019-04-16', '2019-04-17', '2019-04-18',
#                '2019-04-22', '2019-04-23', '2019-04-24', '2019-04-25',
#                '2019-04-26', '2019-04-29',
#                ...
#                '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03',
#                '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09',
#                '2020-04-13', '2020-04-14'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None)

# %%
# convert pandas index to <list> var
nvda_index = nvda.index.tolist()

# %%
type(nvda_index)
# Out:
# list

# %%
len(nvda_index)
# Out:
# 252

# %%
# add new column to dataframe
nvda['date'] = nvda_index
# Out:
# /Users/ryan/anaconda3/envs/py36-fasttext/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nvda.shape
# Out:
# (252, 6)

# %%
nvda.iloc[0]['date']
# Out:
# Timestamp('2019-04-15 00:00:00')

# %% [markdown]
# ### Calculate MA 3 & 10

# %%
# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_nvda = nvda_close.rolling(window=3).mean()
long_rolling_nvda = nvda_close.rolling(window=10).mean()

# %%
type(short_rolling_msft)
# Out:
# pandas.core.frame.DataFrame

# %%
len(short_rolling_nvda)
# Out:
# 251

# %%
# MA3
short_rolling_nvda.iloc[-1]
# Out:
# Close    266.583344
# Name: 2020-04-13 00:00:00, dtype: float64

# %%
# MA10
long_rolling_nvda.iloc[-1]
# Out:
# Close    259.882004
# Name: 2020-04-13 00:00:00, dtype: float64

# %%
def calculate_ma(data=pd.DataFrame, day=3):
    ''' calculate Moving Average (MA)
        params: (DataFrame) @data, e.g. stock closing price
                (int) @day Size of the moving window, e.g. 3 >>> MA3
        return: (DataFrame) MA
    '''
    ma = pd.DataFrame.rolling(data, window=day).mean()
    return ma

# %%
def calculate_mas(data=pd.DataFrame, days=[], return_type='dict'):
    ''' calculate list of Moving Average (MA)
        params: (DataFrame) @data, e.g. stock closing price
                (list)(int) @days, e.g. [3, 10, 20] >>> MA3, MA10, MA20
                (str) @return_type, e.g. 'dict' >>> return dict result, 'list' >>> return list result
        return: (list/dict)(DataFrame) list of MA
    '''
    mas = {} if return_type == 'dict' else []
    for day in days:
        if return_type == 'dict':
            mas[day] = calculate_ma(data=data, day=day) # return dict
        else:
            mas.append(calculate_ma(data=data, day=day)) # return list
    return mas

# %%
# Calculate MA
mas = [3, 10, 20]
stock_mas = calculate_mas(data=nvda['Close'], days=mas)

# %%
stock_mas[0][-5:]
# Out:
# Date
# 2020-04-07    257.113332
# 2020-04-08    264.793335
# 2020-04-09    262.976674
# 2020-04-13    266.583344
# 2020-04-14    272.250010
# Name: Close, dtype: float64

# %%
# Add MA to DataFrame
for ma in mas:
    nvda[f'MA{ma}'] = stock_mas

# %%
A = [1,3,7,11,13,17]; B = [2,4,6,8,14,15]
def find_crossing_point(A: 'List[int]', B: 'List[int]') -> 'List[int]':
    ''' find the two MA crossing point
    '''
    index = []
    for i in range(1, len(A)-1):
        if (A[i-1]>B[i-1] and A[i]<B[i]) or (A[i-1]<B[i-1] and A[i]>B[i]):
            index.append(i)
    return index

find_crossing_point(A, B)
# Out:
# [2, 4]

# %%
nvda[-5:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-07  277.299988  278.250000  257.299988  259.029999  259.029999
# 2020-04-08  263.410004  267.950012  260.600006  266.950012  266.950012
# 2020-04-09  272.000000  272.920013  260.420013  262.950012  262.950012
# 2020-04-13  260.549988  270.200012  257.000000  269.850006  269.850006
# 2020-04-14  275.000000  285.320007  273.889313  283.950012  283.950012
#
#               Volume         ma3        ma_3
# Date
# 2020-04-07  19613000  257.113332  257.113332
# 2020-04-08  13561100  264.793335  264.793335
# 2020-04-09  13156200  262.976674  262.976674
# 2020-04-13   9933900  266.583344  266.583344
# 2020-04-14  13053691  272.250010  272.250010

# %%
nvda_close[-10:]
# Out:
#                  Close
# Date
# 2020-03-30  265.589996
# 2020-03-31  263.600006
# 2020-04-01  243.070007
# 2020-04-02  255.470001
# 2020-04-03  243.910004
# 2020-04-06  268.399994
# 2020-04-07  259.029999
# 2020-04-08  266.950012
# 2020-04-09  262.950012
# 2020-04-13  269.850006

# %% [markdown]
# ## Plot graph

# %%
stock_close = nvda_close[-100:]
# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling = stock_close.rolling(window=3).mean()
long_rolling = stock_close.rolling(window=10).mean()

## Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(stock_close.index, stock_close, label='NVDA')
ax.plot(short_rolling.index, short_rolling, label='3 days rolling')
ax.plot(long_rolling.index, long_rolling, label='10 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()

# %%
ax.plot(nvda_close.index, nvda_close, label='NVDA')
ax.plot(short_rolling_nvda.index, short_rolling_nvda, label='20 days rolling')
ax.plot(long_rolling_nvda.index, long_rolling_nvda, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
# Out:
# <bound method _AxesBase.draw of <matplotlib.axes._subplots.AxesSubplot object at 0x1183b0080>>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## yahoo_fin
#
# http://theautomatic.net/2018/07/31/how-to-get-live-stock-prices-with-python/
#
# http://theautomatic.net/yahoo_fin-documentation/

# %%
# import stock_info module from yahoo_fin
from yahoo_fin import stock_info as si

# %%
# get live price of Apple
si.get_live_price("NVDA")
# Out:
# 260.5

# %% [markdown]
# ## pandas_datareader

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
start_date = '2020-04-01'
end_date = '2020-04-13'
data.DataReader('NVDA', 'yahoo', start_date, end_date)
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-03-31  275.399994  257.750000  267.200012  263.600006  23749000
# 2020-04-01  261.529999  241.279999  255.649994  243.070007  16422800
# 2020-04-02  256.000000  242.309998  244.240005  255.470001  16894100
# 2020-04-03  255.630005  238.389999  253.960007  243.910004  16580300
# 2020-04-06  269.880005  252.929993  255.240005  268.399994  18197100
# 2020-04-07  278.250000  257.299988  277.299988  259.029999  19613000
# 2020-04-08  267.950012  260.600006  263.410004  266.950012  13561100
# 2020-04-09  272.920013  260.420013  272.000000  262.950012  13156200
# 2020-04-13  265.100006  257.000000  260.549988  262.114990   3571689
#
#              Adj Close
# Date
# 2020-03-31  263.600006
# 2020-04-01  243.070007
# 2020-04-02  255.470001
# 2020-04-03  243.910004
# 2020-04-06  268.399994
# 2020-04-07  259.029999
# 2020-04-08  266.950012
# 2020-04-09  262.950012
# 2020-04-13  262.114990

# %%
# find code in bucket, e.g. this is code [cxx1] test >>> 'cxx1'
import re
pattern = '(?<=\[).*?(?=\])'
text = 'ab[abc]c[xx1]'
matches = re.findall(pattern, text)
print(len(matches))
matches
# Out:
# 2
# ['abc', 'xx1']

# %%
# find code in bucket, e.g. 'this is code [cxx1] test' >>> 'cxx1'
def get_code_from_text(text:'string')->'string':
    ''' get coupon code from text, e.g. 'hi亞博小食[cxx1]' >>> 'cxx1'
        params: (string) @text
        return: (string) code
    '''
    pattern = r'(?<=\[).*?(?=\])' # find value in [], e.g. 'hi亞博小食[cxx1]' >>> ['cxx1']
    matches = re.findall(pattern, text)
    return matches

text = 'ab[abcc[xx1]'
get_code_from_text(text)
# Out:
# ['abcc[xx1']

# %%
import hashlib, base64

# %%
import hashlib, base64

def shortcode(url):
    """
    Our main shortening function. The rationale here is that
    we are relying on the fact that for similarly sized inputs
    such as URLs the potential for collision in the 32 last bits
    of the MD5 hash is rather unlikely.

    The following things happen, in order:

    * compute the md5 digest of the given source
    * extract the lower 4 bytes
    * base64 encode the result
    * remove trailing padding if it exists

    Of course, should a collision happen, we will evict the previous
    key.
    """
    # return base64.b64encode(md5.new(url).digest()[-4:]).replace('=','').replace('/','_')
    # return base64.b64encode(hashlib.md5(url).digest()[-4:]).replace('=','').replace('/','_')
    code = base64.b64encode(md5(url)[-4:]).replace('=','').replace('/','_')
    return code

def md5(text=''):
    return hashlib.md5(text.encode('utf-8')).hexdigest()

text = 'this is testing'
code = shortcode(text)
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-87f6b440828f> in <module>()
#      27
#      28 text = 'this is testing'
# ---> 29 code = shortcode(text)
#      30 print(text)
#
# <ipython-input-81-87f6b440828f> in shortcode(url)
#      20     # return base64.b64encode(md5.new(url).digest()[-4:]).replace('=','').replace('/','_')
#      21     # return base64.b64encode(hashlib.md5(url).digest()[-4:]).replace('=','').replace('/','_')
# ---> 22     code = base64.b64encode(md5(url)[-4:]).replace('=','').replace('/','_')
#      23     return code
#      24
#
# ~/anaconda3/envs/py36-fasttext/lib/python3.6/base64.py in b64encode(s, altchars)
#      56     application to e.g. generate url or filesystem safe Base64 strings.
#      57     """
# ---> 58     encoded = binascii.b2a_base64(s, newline=False)
#      59     if altchars is not None:
# ...

# %%
text = 'this is testing'
text_md5 = hashlib.md5(text.encode('utf-8')).hexdigest()
print(text_md5)
text_md5[-4:]
print(text_md5.encode())
# Out:
# 1e02f65a6d0b3b10337c02170185ff5d
# b'1e02f65a6d0b3b10337c02170185ff5d'

# %%
import random
import string

def random_token(size = 6):
    """
    Generates a random string of 6 chars , use size argument 
    to change the size of token.
    Returns a valid token of desired size , 
    *default is 6 chars
    """
    BASE_LIST = string.digits + string.letters

    token = ''.join((random.choice(BASE_LIST)) for char in range(size))
    return token
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-60f590ad8b54> in <module>()
#       1 import base64
# ----> 2 encoded = base64.b64encode('base64 encoded string')
#       3 encoded
#
# ~/anaconda3/envs/py36-fasttext/lib/python3.6/base64.py in b64encode(s, altchars)
#      56     application to e.g. generate url or filesystem safe Base64 strings.
#      57     """
# ---> 58     encoded = binascii.b2a_base64(s, newline=False)
#      59     if altchars is not None:
#      60         assert len(altchars) == 2, repr(altchars)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
from hashids import Hashids
# hashids = Hashids()
salt = 'Asiabots_Own_Hashids_Salt'; min_length=4; allow_alphabet = 'acdefghijkmnprstuvxyzABCEFGHJKLMNPQRSTUVXY1234567890'
hashids = Hashids(salt=salt, min_length=min_length, alphabet=allow_alphabet)

# %%
# numbers = 123, 456
hashid = hashids.encode(4) # 'Mj3'
hashid
# Out:
# 'dNXz'

# %%
ids = hashids.decode('rxkz')
ids
# Out:
# (1,)

# %%
from hashids import Hashids
hashids = Hashids()
ids = hashids.decode('jR')
ids
# Out:
# (1,)
