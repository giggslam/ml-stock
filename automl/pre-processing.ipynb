# %% [markdown]
# # Finance Data Pre-processing
#
# 1. import data by yfinance
# 2. calculate the SMA
# 3. export data to csv by pandas

# %% [markdown]
# ## 1. import data by yfinance

# %%
import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")
print(nvda)
"""
returns
<yfinance.Ticker object at 0x1a1715e898>
"""
# Out:
# yfinance.Ticker object <NVDA>
# '\nreturns\n<yfinance.Ticker object at 0x1a1715e898>\n'

# %%
# get stock info
nvda.info
# Out:
# {'zip': '95051',
#  'sector': 'Technology',
#  'fullTimeEmployees': 13775,
#  'longBusinessSummary': "NVIDIA Corporation operates as a visual computing company worldwide. It operates in two segments, GPU and Tegra Processor. The GPU segment offers processors, which include GeForce for PC gaming and mainstream PCs; GeForce NOW for cloud-based gaming; Quadro for design professionals working in computer-aided design, video editing, special effects, and other creative applications; Tesla for artificial intelligence (AI) utilizing deep learning, accelerated computing, and general purpose computing; GRID, which provides power of NVIDIA graphics through the cloud and datacenters; DGX for AI scientists, researchers, and developers; and EGX for accelerated AI computing at the edge. The Tegra Processor segment provides processors comprising SHIELD devices and services designed to harness the power of mobile-cloud to revolutionize home entertainment, AI, and gaming; AGX, a power-efficient AI computing platform for intelligent edge devices; DRIVE AGX for self-driving vehicles; Clara AGX for medical instruments; and Jetson AGX for robotics and other embedded use. The company's products are used in gaming, professional visualization, datacenter, and automotive markets. NVIDIA Corporation sells its products to original equipment manufacturers, original device manufacturers, system builders, add-in board manufacturers, retailers/distributors, Internet and cloud service providers, automotive manufacturers and tier-1 automotive suppliers, mapping companies, start-ups, and other ecosystem participants. NVIDIA Corporation was founded in 1993 and is headquartered in Santa Clara, California.",
#  'city': 'Santa Clara',
#  'phone': '408 486 2000',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.nvidia.com',
#  'maxAge': 1,
#  'address1': '2788 San Tomas Expressway',
#  'industry': 'Semiconductors',
#  'previousClose': 339.48,
#  'regularMarketOpen': 342.18,
#  'twoHundredDayAverage': 259.02548,
#  'trailingAnnualDividendYield': 0.0018852361,
#  'payoutRatio': 0.11960000000000001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 355.02,
#  'navPrice': None,
#  'averageDailyVolume10Day': 20764971,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 339.48,
#  'fiftyDayAverage': 310.71176,
#  'trailingAnnualDividendRate': 0.64,
#  'open': 342.18,
#  'toCurrency': None,
#  'averageVolume10days': 20764971,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 0.64,
#  'exDividendDate': 1591228800,
#  'beta': 1.330135,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 339.4145,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 78.54424,
#  'regularMarketVolume': 18647994,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 218337296384,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 15716325,
#  'priceToSalesTrailing12Months': 19.997921,
#  'dayLow': 339.4145,
#  'ask': 354.5,
#  'ytdReturn': None,
#  'askSize': 2900,
#  'volume': 18647994,
#  'fiftyTwoWeekHigh': 367.27,
#  'forwardPE': 38.884995,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 0.6000000000000001,
#  'fiftyTwoWeekLow': 132.6,
#  'bid': 354.06,
#  'tradeable': False,
#  'dividendYield': 0.0019,
#  'bidSize': 900,
#  'dayHigh': 355.02,
#  'exchange': 'NMS',
#  'shortName': 'NVIDIA Corporation',
#  'longName': 'NVIDIA Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'NVDA',
#  'messageBoardId': 'finmb_32307',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 16.761,
#  'beta3Year': None,
#  'profitMargins': 0.25609000000000004,
#  'enterpriseToEbitda': 56.708,
#  '52WeekChange': 1.6537600000000001,
#  'morningStarRiskRating': None,
#  'forwardEps': 9.13,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 615000000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 19.925,
#  'sharesShort': 10030334,
#  'sharesPercentSharesOut': 0.016300000000000002,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1579996800,
#  'heldPercentInstitutions': 0.69228,
#  'netIncomeToCommon': 2796000000,
#  'trailingEps': 4.52,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.10926056,
#  'priceToBook': 17.817818,
#  'heldPercentInsiders': 0.041510000000000005,
#  'nextFiscalYearEnd': 1643155200,
#  'mostRecentQuarter': 1579996800,
#  'shortRatio': 0.84,
#  'sharesShortPreviousMonthDate': 1586908800,
#  'floatShares': 586271520,
#  'enterpriseValue': 182995992576,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1189468800,
#  'lastSplitFactor': '3:2',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.68,
#  'dateShortInterest': 1589500800,
#  'pegRatio': 2.7199999999999998,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.017,
#  'sharesShortPriorMonth': 11993211,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 342.18,
#  'logo_url': 'https://logo.clearbit.com/nvidia.com'}

# %%
# get historical market data (all)
nvda_history = nvda.history(period="max")
nvda_history
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1999-01-22    1.61    1.80    1.43    1.51  67867200.0        0.0
# 1999-01-25    1.63    1.69    1.51    1.67  12762000.0        0.0
# 1999-01-26    1.69    1.72    1.51    1.54   8580000.0        0.0
# 1999-01-27    1.54    1.58    1.46    1.53   6109200.0        0.0
# 1999-01-28    1.53    1.54    1.52    1.53   5688000.0        0.0
# 1999-01-29    1.53    1.53    1.46    1.46   6100800.0        0.0
# 1999-02-01    1.46    1.50    1.46    1.49   3867600.0        0.0
# 1999-02-02    1.46    1.50    1.33    1.37   6602400.0        0.0
# 1999-02-03    1.35    1.42    1.34    1.40   1878000.0        0.0
# 1999-02-04    1.42    1.51    1.40    1.48   4548000.0        0.0
# 1999-02-05    1.50    1.53    1.46    1.52   3421200.0        0.0
# 1999-02-08    1.53    1.53    1.47    1.47   3852000.0        0.0
# 1999-02-09    1.50    1.51    1.39    1.41   2174400.0        0.0
# 1999-02-10    1.41    1.45    1.37    1.39   3705600.0        0.0
# 1999-02-11    1.40    1.57    1.40    1.51   3306000.0        0.0
# 1999-02-12    1.53    1.61    1.53    1.60   2743200.0        0.0
# 1999-02-16    1.63    1.70    1.45    1.61   5275200.0        0.0
# 1999-02-17    1.57    1.59    1.50    1.52   1693200.0        0.0
# 1999-02-18    1.57    1.59    1.51    1.55   1767600.0        0.0
# 1999-02-19    1.53    1.63    1.51    1.60   1884000.0        0.0
# 1999-02-22    1.63    1.65    1.52    1.61   5131200.0        0.0
# 1999-02-23    1.65    1.72    1.55    1.69   3452400.0        0.0
# 1999-02-24    1.94    2.01    1.78    1.82  15319200.0        0.0
# 1999-02-25    1.90    1.96    1.74    1.76   3728400.0        0.0
# 1999-02-26    1.78    1.84    1.67    1.68   4315200.0        0.0
# 1999-03-01    1.73    1.76    1.61    1.69   2304000.0        0.0
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-05-22  353.01  363.72  348.53  361.05  25969100          0             0
# 2020-05-26  366.27  367.27  346.88  348.71  19269500          0             0
# 2020-05-27  345.00  345.31  319.87  341.01  29397300          0             0
# 2020-05-28  336.49  350.42  335.17  339.48  18372400          0             0
# 2020-05-29  342.18  355.02  339.40  355.02  18631400          0             0

# %%
data
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-05-22  353.01  363.72  348.53  361.05  25969100          0             0
# 2020-05-26  366.27  367.27  346.88  348.71  19269500          0             0
# 2020-05-27  345.00  345.31  319.87  341.01  29397300          0             0
# 2020-05-28  336.49  350.42  335.17  339.48  18372400          0             0
# 2020-05-29  342.18  355.02  339.40  355.02  18631400          0             0

# %%
# reset DataFrame index to RangeIndex
data1 = data.reset_index()
data1
# Out:
#         Date    Open    High     Low   Close    Volume  Dividends  \
# 0 2020-05-22  353.01  363.72  348.53  361.05  25969100          0
# 1 2020-05-26  366.27  367.27  346.88  348.71  19269500          0
# 2 2020-05-27  345.00  345.31  319.87  341.01  29397300          0
# 3 2020-05-28  336.49  350.42  335.17  339.48  18372400          0
# 4 2020-05-29  342.18  355.02  339.40  355.02  18631400          0
#
#    Stock Splits
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
# data1 = data.reset_index()

date = '2020-05-03'
end_date = data1[data1['Date']<=date].tolist()[0] if data1[data1['Date']<=date].any() else None
# end_date = data1.index[data1['Date']<=date].tolist()[0] if data1.index[data1['Date']<=date].any() else None
print(f'end_date:{end_date}')
# data = data[:end_date]
# data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-91f52fca7dae> in <module>()
#       2
#       3 date = '2020-05-03'
# ----> 4 end_date = data1[data1['Date']<=date].tolist()[0] if data1[data1['Date']<=date].any() else None
#       5 # end_date = data1.index[data1['Date']<=date].tolist()[0] if data1.index[data1['Date']<=date].any() else None
#       6 print(f'end_date:{end_date}')
#
# ~/anaconda3/envs/py36-fasttext/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477         raise ValueError("The truth value of a {0} is ambiguous. "
#    1478                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1479                          .format(self.__class__.__name__))
#    1480
#    1481     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data1[data1['Date']<=date]

# %%
data1['Close'].iat[-1]

# %%
data1

# %%
for i in nvda_history.index:
    ma3 = f'xxx:{i}'
    nvda_history.at[i, 'ma3xx'] = ma3

# %%
type(nvda_history)
# Out:
# pandas.core.frame.DataFrame

# %%
nvda_history.shape
# Out:
# (5, 8)

# %% [markdown]
# ## 2. export data to csv

# %%
csv_export_filename = 'nvda.csv'
nvda_history.to_csv(csv_export_filename, header=True)

# %%
stock_ids = ['NVDA']
period = '1y'; start = '2020-04-27'; end='2020-04-28'; group_by='ticker'
data = yf.download(stock_ids, end=end, group_by=group_by)
data

# %%
type(data)

# %%
csv_export_filename = 'nvda.1.csv'
data.to_csv(csv_export_filename, header=True)

# %% [markdown]
# ## 3. Mass download data

# %%
# stocks = "NVDA TSLA UGLD"
stocks = ['NVDA','TSLA','UGLD']
period = '5y' # max, 1y, 5y
data = yf.download(stocks, period=period, group_by="ticker")
print(type(data))
print(data.shape)
# Out:
# [*********************100%***********************]  3 of 3 completed
# <class 'pandas.core.frame.DataFrame'>
# (1259, 18)

# %%
data = yf.download(stocks, period="1y", start='', end='', group_by="ticker")
print(type(data))
print(data.shape)
# Out:
# [*********************100%***********************]  3 of 3 completed
# <class 'pandas.core.frame.DataFrame'>
# (253, 18)

# %%
data
# Out:
#                   UGLD                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 

# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-29  342.179993  355.019989  339.399994  355.019989  355.019989
#
#               Volume
# Date
# 2020-05-29  18631400

# %%
data['NVDA']['Close'][-1:]

# %%
data = yf.download(stocks, period="1y", start='', end='')
print(type(data))
print(data.shape)

# %%
data

# %%
data['Close'][-1:]

# %%
data['Close']['NVDA'][-1:]

# %%
ma3 = pd.DataFrame.rolling(data['NVDA']['Close'], window=3).mean()
ma3.shape

ma3.shape
ma3.tail(5)

# %%
type(data['NVDA']['Close'][-1:])

# %%
data['NVDA']['Close'][-1:]

# %%
type(data['NVDA']['Close'][-1:][0])

# %%
data['NVDA']['Close'][-1:][0]

# %%
data.describe()

# %%
# Get the NVDA timeseries. This now returns a Pandas Series object indexed by date.
nvda = data.loc[:, 'NVDA']

# %%
type(nvda)

# %%
nvda.shape

# %%
len(nvda)

# %%
nvda.tail(5)

# %%
# get the closing price into new DataFrame
nvda_close = nvda.filter(['Close'], axis=1)

# %%
type(nvda_close)

# %%
nvda_close.shape

# %%
len(nvda_close)

# %%
nvda_close.tail(5)

# %%
type(nvda_close.index)

# %%
nvda_close.index

# %%
# convert pandas index to <list> var
nvda_index = nvda.index.tolist()

# %%
type(nvda_index)

# %%
len(nvda_index)

# %%
# add new column to dataframe
nvda['date'] = nvda_index

# %%
nvda.shape

# %%
nvda.iloc[0]['date']

# %% [markdown]
# ### Calculate MA 3 & 10

# %%
# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_nvda = nvda_close.rolling(window=3).mean()
long_rolling_nvda = nvda_close.rolling(window=10).mean()

# %%
type(short_rolling_msft)

# %%
len(short_rolling_nvda)

# %%
# MA3
short_rolling_nvda.iloc[-1]

# %%
# MA10
long_rolling_nvda.iloc[-1]

# %%
def calculate_ma(data=pd.DataFrame, day=3):
    ''' calculate Moving Average (MA)
        params: (DataFrame) @data, e.g. stock closing price
                (int) @day Size of the moving window, e.g. 3 >>> MA3
        return: (DataFrame) MA
    '''
    ma = pd.DataFrame.rolling(data, window=day).mean()
    return ma

# %%
def calculate_mas(data=pd.DataFrame, days=[], return_type='dict'):
    ''' calculate list of Moving Average (MA)
        params: (DataFrame) @data, e.g. stock closing price
                (list)(int) @days, e.g. [3, 10, 20] >>> MA3, MA10, MA20
                (str) @return_type, e.g. 'dict' >>> return dict result, 'list' >>> return list result
        return: (list/dict)(DataFrame) list of MA
    '''
    mas = {} if return_type == 'dict' else []
    for day in days:
        if return_type == 'dict':
            mas[day] = calculate_ma(data=data, day=day) # return dict
        else:
            mas.append(calculate_ma(data=data, day=day)) # return list
    return mas

# %%
# Calculate MA
mas = [3, 10, 20]
stock_mas = calculate_mas(data=nvda['Close'], days=mas)

# %%
stock_mas[0][-5:]

# %%
# Add MA to DataFrame
for ma in mas:
    nvda[f'MA{ma}'] = stock_mas

# %%
A = [1,3,7,11,13,17]; B = [2,4,6,8,14,15]
def find_crossing_point(A: 'List[int]', B: 'List[int]') -> 'List[int]':
    ''' find the two MA crossing point
    '''
    index = []
    for i in range(1, len(A)-1):
        if (A[i-1]>B[i-1] and A[i]<B[i]) or (A[i-1]<B[i-1] and A[i]>B[i]):
            index.append(i)
    return index

find_crossing_point(A, B)

# %%
nvda[-5:]

# %%
nvda_close[-10:]

# %% [markdown]
# ## Plot graph

# %%
stock_close = nvda_close[-100:]
# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling = stock_close.rolling(window=3).mean()
long_rolling = stock_close.rolling(window=10).mean()

## Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(stock_close.index, stock_close, label='NVDA')
ax.plot(short_rolling.index, short_rolling, label='3 days rolling')
ax.plot(long_rolling.index, long_rolling, label='10 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()

# %%
ax.plot(nvda_close.index, nvda_close, label='NVDA')
ax.plot(short_rolling_nvda.index, short_rolling_nvda, label='20 days rolling')
ax.plot(long_rolling_nvda.index, long_rolling_nvda, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## yahoo_fin
#
# http://theautomatic.net/2018/07/31/how-to-get-live-stock-prices-with-python/
#
# http://theautomatic.net/yahoo_fin-documentation/

# %%
# import stock_info module from yahoo_fin
from yahoo_fin import stock_info as si

# %%
# get live price of Apple
si.get_live_price("NVDA")

# %% [markdown]
# ## pandas_datareader

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
start_date = '2020-04-01'
end_date = '2020-04-13'
data.DataReader('NVDA', 'yahoo', start_date, end_date)

# %%
import traceback
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s.%(msecs)03d %(levelname)s:\t%(message)s', datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger(__name__)

# %%
def calcaulate_mas_crossing_points(A: 'List[int]', B: 'List[int]') -> 'List[int]':
    ''' find the two MA crossing point
        params: (list)(int) @A, e.g. MA3
                (list)(int) @B, e.g. MA10
        return: (list)(int) crossing point (0: two line parallel, 1: crossing signal)
    '''
    try:
        print('calcaulate_mas_crossing_points() ...')
        # crossing_points = []
        crossing_points = [0 for i in range(len(A))]
        for i in range(1, len(A)):
            if (A[i-1]>B[i-1] and A[i]<B[i]) or (A[i-1]<B[i-1] and A[i]>B[i]):
                crossing_points[i] = 1
                # crossing_points.append(1)
            # else:
                # crossing_points.append(0)
    except Exception as e:
        print('ERROR: calcaulate_mas_crossing_points()')
        print(traceback.format_exc())
        print(e)
    finally:
        print('... calcaulate_mas_crossing_points()')
        return crossing_points

# %%
A = [1, 3, 5, 7, 9]
B = [2, 4, 4, 6, 10]
C = calcaulate_mas_crossing_points(A, B)
C
# Out:
# calcaulate_mas_crossing_points() ...
# ... calcaulate_mas_crossing_points()
# [0, 0, 1, 0, 1]
